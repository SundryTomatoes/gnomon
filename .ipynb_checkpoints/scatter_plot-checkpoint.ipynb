# 300    Chick Evans Field House        Husky Food Pantry      2.0
# 301    Chick Evans Field House        Husky Food Pantry      2.0
# 302    Chick Evans Field House        Husky Food Pantry      4.0
# 303                    outside             travel - car      4.0
# 304                    outside             travel - car      4.0
# 305                    outside             travel - car      1.0
# 306                    outside             travel - car      1.0
# 307                       Home               Final shot      4.0
#
# [308 rows x 6 columns]

# %%
data.loc[1, "Datetime"] - data.loc[0, "Datetime"]
# Out:
# Timedelta('0 days 00:03:16')

# %%
def timePerLoc(df):
    """
    Takes a dataframe. Calculates the amount of time spent at each location
    each time a building was entered.
    """
    newDF = pd.DataFrame()
    
    loc = df.loc[0, "Location"]
    start = df.loc[0, "Datetime"]
    day = df.loc[0, "Day"]
    count = 1
    
    for i in df.index.values[1:]:
        if (df.loc[i, "Location"] != loc) or (df.loc[i, "Day"] != day):
            diff = df.loc[i, "Datetime"] - start
            D = {"Location": loc, 
                 "Start": start, 
                 "Day": day, 
                 "Tot_min": (diff.seconds/60), 
                 "n_pics": count}
            newDF = newDF.append(D, ignore_index=True)
            
            loc = df.loc[i, "Location"]
            start = df.loc[i, "Datetime"]
            day = df.loc[i, "Day"]
            count = 0
        count += 1
        
    return newDF
            
    # Will the last index be counted?

# %%
locs = timePerLoc(data)

# %%
locs
# Out:
#           Day                        Location               Start  \
# 0      monday                         outside 2019-02-04 14:21:46
# 1      monday       Founders Memorial Library 2019-02-04 14:46:46
# 2      monday                         outside 2019-02-04 16:52:56
# 3      monday                   CSCI Building 2019-02-04 16:57:04
# 4      monday                         outside 2019-02-04 18:43:45
# 5      monday                    Faraday Hall 2019-02-04 18:47:30
# 6      monday                         outside 2019-02-04 20:40:47
# 7     tuesday                         outside 2019-02-05 11:07:40
# 8     tuesday  Recreation and Wellness Center 2019-02-05 11:23:11
# 9     tuesday                         outside 2019-02-05 12:16:25
# 10    tuesday                   CSCI Building 2019-02-05 12:24:47
# 11    tuesday                         outside 2019-02-05 14:04:04
# 12    tuesday                    Faraday Hall 2019-02-05 14:06:51
# 13    tuesday                         outside 2019-02-05 16:18:09
# 14  wednesday                         outside 2019-02-06 14:31:32
# 15  wednesday       Founders Memorial Library 2019-02-06 14:44:58
# 16  wednesday                   CSCI Building 2019-02-06 16:57:10
# 17  wednesday                         outside 2019-02-06 18:23:58
# 18   thursday                         outside 2019-02-07 11:08:18
# 19   thursday  Recreation and Wellness Center 2019-02-07 11:22:02
# 20   thursday                         outside 2019-02-07 12:22:05
# 21   thursday                   CSCI Building 2019-02-07 12:31:05
# 22   thursday                         outside 2019-02-07 14:00:04
# 23   thursday                    Faraday Hall 2019-02-07 14:06:07
# 24   thursday                         outside 2019-02-07 16:05:34
# 25   thursday                            Home 2019-02-07 16:22:34
# 26   thursday                         outside 2019-02-07 16:46:51
# 27   thursday         Chick Evans Field House 2019-02-07 16:57:25
# 28   thursday                         outside 2019-02-07 17:35:01
#
#         Tot_min  n_pics
# 0     25.000000     9.0
# 1    126.166667    29.0
# 2      4.133333     1.0
# 3    106.683333    32.0
# 4      3.750000     1.0
# 5    113.283333    18.0
# 6    866.883333     7.0
# 7     15.516667     4.0
# 8     53.233333    16.0
# 9      8.366667     2.0
# 10    99.283333    23.0
# 11     2.783333     1.0
# 12   131.300000    16.0
# 13  1333.383333     4.0
# 14    13.433333     4.0
# 15   132.200000    29.0
# 16    86.800000    25.0
# 17  1004.333333     5.0
# 18    13.733333     5.0
# 19    60.050000    15.0
# 20     9.000000     2.0
# 21    88.983333    13.0
# 22     6.050000     2.0
# 23   119.450000    17.0
# 24    17.000000     5.0
# 25    24.283333     7.0
# 26    10.566667     3.0
# 27    37.600000     8.0
# 28    18.600000     4.0

# %%
sns.set()

sns.scatterplot(x="Tot_min", y="n_pics", data=locs)

# %%
# Create a husk object and read in all images from the week

husky = husk()

for i in data.index.values:
    husky.add_image(filename = data.loc[i, 'Image filename'])

husky.rotate_all('r')

husky.blend()

# %matplotlib inline
husky.show_comp()
# Out:
# Picture resolutions are not identical. Resizing images...
# /opt/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /opt/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Images resized.

# %% [markdown]
# # Histograms

# %%
cmap = matplotlib.cm.get_cmap('Greys_r')


i=100
img = copy.copy(husky.imgs[i])

img_gray = skimage.color.rgb2gray(img)


y, x = skimage.exposure.histogram(img_gray.flatten(), nbins=20)


plt.bar(x, y, width=.045, color=[cmap(val) for val in x], edgecolor='black', linewidth=1);

# %%
# A function to prepare the data for creating a stacked bar chart of pixel
# lightness or darkness by time of day

def make_xy(df, cluster_n, imgs, nbins=20):
    """
    Takes a dataframe (with datetime stamp of each photo), a cluster number,
    a set of images, and the number of bins to create and returns x positions 
    and y lengths for stacked bar charts.
    """
    # Create a working dataframe with only the cluster you're looking at
    ## Cluster 0 means all clusters
    if cluster_n == 0: 
        workingdf = copy.copy(df)
    else:
        workingdf = df[df['Cluster'] == cluster_n]
    
    # Create new columns for Hour and Minute features from the datetime
    workingdf['Hour'] = workingdf['Datetime'].apply(lambda dt: dt.hour)
    workingdf['Minute'] = workingdf['Datetime'].apply(lambda dt: dt.minute)
    workingdf['min_past_7'] = (workingdf['Hour'] - 7) * 60 + workingdf['Minute']
    
    # Sort the dataframe by (1) minute, then by (2) hour
    workingdf = workingdf.sort_values(by="min_past_7")
    
    # Find the first bar in the set (nearest multiple of 12 less than first #)
    bar_1 = workingdf.iloc[0]['min_past_7']
    while bar_1 % 12:
        bar_1 -= 1
        
    # Find the last bar in the set (nearest multiple of 12 greater than first #)
    bar_n = workingdf.iloc[-1]['min_past_7']
    while bar_n % 12:
        bar_n += 1
    
    # Find the number of bars by the distance between the first and last photos
    # One bar will represent 12 minutes, so there are 5 bars per hour
    n_bars = (bar_n - bar_1) / 12
    
    # Initialize two arrays of zeros of the proportions n_bars x n_bins
    xs = np.zeros((nbins, int(n_bars)), dtype=int)
    ys = np.zeros((nbins, int(n_bars)), dtype=int)
    # Initialize one array to be used for positioning of bar on the dial
    bar_begs = np.zeros(int(n_bars), dtype=int)
    
    next_bar = copy.copy(bar_1)
    i = 0
    
    for n in range(int(n_bars)):
        next_bar += 12
        bar_begs[n] = next_bar # Store the end position of the bar
        
        # Find all photos that belong in the current bar and add their bin values
        while ((i < len(workingdf.index.values)) and (workingdf.iloc[i]['min_past_7'] < next_bar)):
            img_gray = skimage.color.rgb2gray(imgs[workingdf.index.values[i]])
            y, x = skimage.exposure.histogram(img_gray.flatten(), nbins=nbins)
        
            for j in range(nbins):
                xs[j][n] += x[j]
                ys[j][n] += y[j]
                
            i+=1
        
    return xs, ys, bar_begs

# %%
nbins = 20
cluster = 1

x, y, bar_begs = make_xy(data, cluster, husky.imgs, nbins=nbins)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
N = len(data[data['Cluster'] == cluster])
bottom = 0
width = 0.045
# cmap = matplotlib.cm.get_cmap('Greys_r')
cmap = matplotlib.cm.get_cmap('viridis')

ax = plt.subplot(111)

bottoms = np.zeros(x.shape[1])

for i in range(x.shape[0]):
    ax.bar([val for val in range(x.shape[1])], y[i], width=0.5, bottom=bottoms, 
           color=cmap(i/x.shape[0]), edgecolor='black', linewidth=0.00)
    bottoms += np.array(y[i])

# %%
df = copy.copy(data)
df = df[df['Cluster'] == cluster]

df['Hour'] = df['Datetime'].apply(lambda dt: dt.hour)
df['Minute'] = df['Datetime'].apply(lambda dt: dt.minute)
df['min_past_7'] = (df['Hour'] - 7) * 60 + df['Minute']
df = df.sort_values(by="min_past_7")

# %%
df
# Out:
#                Datetime        Day      Image filename  \
# 112 2019-02-05 11:57:50    tuesday  week/img (113).jpg
# 113 2019-02-05 12:00:14    tuesday  week/img (114).jpg
# 114 2019-02-05 12:03:34    tuesday  week/img (115).jpg
# 115 2019-02-05 12:06:58    tuesday  week/img (116).jpg
# 243 2019-02-07 12:09:53   thursday  week/img (244).jpg
# 244 2019-02-07 12:13:58   thursday  week/img (245).jpg
# 265 2019-02-07 14:25:29   thursday  week/img (266).jpg
# 281 2019-02-07 16:08:52   thursday  week/img (282).jpg
# 287 2019-02-07 16:32:23   thursday  week/img (288).jpg
# 288 2019-02-07 16:36:09   thursday  week/img (289).jpg
# 289 2019-02-07 16:39:14   thursday  week/img (290).jpg
# 290 2019-02-07 16:42:26   thursday  week/img (291).jpg
# 291 2019-02-07 16:44:54   thursday  week/img (292).jpg
# 305 2019-02-07 17:44:42   thursday  week/img (306).jpg
# 306 2019-02-07 17:49:03   thursday  week/img (307).jpg
# 222 2019-02-06 18:27:15  wednesday  week/img (223).jpg
# 223 2019-02-06 18:29:57  wednesday  week/img (224).jpg
# 224 2019-02-06 18:33:28  wednesday  week/img (225).jpg
# 72  2019-02-04 18:47:30     monday   week/img (73).jpg
# 90  2019-02-04 20:40:47     monday   week/img (91).jpg
# 91  2019-02-04 20:43:27     monday   week/img (92).jpg
# 93  2019-02-04 20:48:43     monday   week/img (94).jpg
# 94  2019-02-04 20:51:32     monday   week/img (95).jpg
# 95  2019-02-04 20:53:29     monday   week/img (96).jpg
# 96  2019-02-04 20:57:22     monday   week/img (97).jpg
#
#                            Location                  Purpose  Cluster  Hour  \
# 112  Recreation and Wellness Center                  workout      1.0    11
# 113  Recreation and Wellness Center                  workout      1.0    12
# 114  Recreation and Wellness Center                  workout      1.0    12
# 115  Recreation and Wellness Center                  workout      1.0    12
# 243  Recreation and Wellness Center                  workout      1.0    12
# 244  Recreation and Wellness Center                  workout      1.0    12
# 265                    Faraday Hall  Office Hours - CSCI 340      1.0    14
# 281                         outside          travel - biking      1.0    16
# 287                            Home        Rest & Relaxation      1.0    16
# 288                            Home        Rest & Relaxation      1.0    16
# 289                            Home        Rest & Relaxation      1.0    16
# 290                            Home        Rest & Relaxation      1.0    16
# 291                            Home        Rest & Relaxation      1.0    16
# 305                         outside             travel - car      1.0    17
# 306                         outside             travel - car      1.0    17
# 222                         outside          travel - biking      1.0    18
# 223                         outside          travel - biking      1.0    18
# 224                         outside          travel - biking      1.0    18
# 72                     Faraday Hall  Office Hours - CSCI 340      1.0    18
# 90                          outside         travel - walking      1.0    20
# 91                          outside         travel - walking      1.0    20
# 93                          outside         travel - walking      1.0    20
# 94                          outside         travel - walking      1.0    20
# 95                          outside         travel - walking      1.0    20
# 96                          outside         travel - walking      1.0    20
#
#      Minute  min_past_7
# 112      57         297
# 113       0         300
# 114       3         303
# 115       6         306
# 243       9         309
# 244      13         313
# 265      25         445
# 281       8         548
# 287      32         572
# 288      36         576
# 289      39         579
# 290      42         582
# 291      44         584
# 305      44         644
# 306      49         649
# 222      27         687
# 223      29         689
# 224      33         693
# 72       47         707
# 90       40         820
# 91       43         823
# 93       48         828
# 94       51         831
# 95       53         833
# 96       57         837

# %%
nbins = 255
cluster = 5

x, y, bar_begs = make_xy(data, cluster, husky.imgs, nbins=nbins)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# One hour on the dial is represented by Pi / 10 degrees

N = len(data[data['Cluster'] == cluster])
bottom = 8_000_000
width = np.pi / 50 # Each bar represents one fifth of an hour
radial_bar_begs = (bar_begs // 12) * (np.pi / 50) - (width / 2) # Position of bars on radial dial

# Set color map for the image
# cmap = matplotlib.cm.get_cmap('Greys_r')
cmap = matplotlib.cm.get_cmap('viridis')
col_vals = np.linspace(0.0, 1.0, num=len(x), endpoint=True) # Determines the hue for each level of the stacked bar

ax = plt.subplot(111, projection='polar')
# rad_beg = np.linspace((np.pi*3/11), 13*np.pi / 11, N, endpoint=True)

bottoms = np.zeros(len(x[0])) + bottom

for i in range(len(x)):
    ax.bar(radial_bar_begs, y[i], width=0.05, bottom=bottoms,
           color=cmap(col_vals[i]), edgecolor='black', linewidth=0.000, 
           alpha=0.9)
    bottoms += np.array(y[i])

linealpha = 0.5
linewidth = 0.2
# ax.axhline(1, alpha=linealpha, linewidth=linewidth, color='black')
plt.vlines(0, ymin=0, ymax=bottom, alpha=linealpha+.3, linewidth=linewidth+.09, color='black')
plt.vlines(np.pi/2, ymin=0, ymax=bottom, alpha=linealpha+.3, linewidth=linewidth+.09, color='black')
plt.vlines(np.pi, ymin=0, ymax=bottom, alpha=linealpha+.3, linewidth=linewidth+.09, color='black')

hours = 0
while hours <= (16*np.pi / 11):
    plt.vlines(hours, ymin=0, ymax=bottom, alpha=linealpha-.2, linewidth=linewidth, color='black')
    hours += np.pi/10


ax.set_theta_zero_location('W')
ax.set_theta_direction(-1)
plt.xticks([])
plt.yticks([])
ax.spines['polar'].set_visible(False)
# plt.show()


path = os.path.join("dial_graphs", "dial_graph%d.png" % (cluster))
plt.savefig(path, dpi=750, bbox_inches='tight', transparent=True)
